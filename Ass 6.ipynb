# %%
print("\nAssignment 6\n")

print("Question NO. 1\n")
print("Define Object Oriented Programming Language\n")
print("Object-oriented programming (OOP) refers to a type of computer programming (software design) in which programmers define the data type of a data structure, and also the types of operations (functions) that can be applied to the data structure. In this way, the data structure becomes an object that includes both data and functions. In addition, programmers can create relationships between one object and another. For example, objects can inherit characteristics from other objects.\n")

print("Question NO. 2\n")
print("List down the Benefits of OOP?\n")
print("1. Improved software-development productivity.\n2. Improved software maintainability.\n3. Faster development.\n4. Lower cost of development.\n5. Higher-quality software\n")

print("Question NO. 3\n")
print("Differentiate between function and method?\n")
print("Function — a set of instructions that perform a task.\nMethod — a set of instructions that are associated with an object.")

print("Question NO. 4\n")
print("Define the following terms:\n1. Class\n2. Object\n3. Attribute\n4. Behavior\n")
print("Class:\nA class describes the contents of the objects that belong to it: it describes an aggregate of data fields (called instance variables), and defines the operations (called methods).\n\nObject:\nan object is an element (or instance) of a class; objects have the behaviors of their class. The object is the actual component of programs, while the class specifies how instances are created and how they behave.\n\nAttribute:\nAn Attribute is a named property of a class. It has a type. It describes the range of values that that property may hold.\n\nBehaviour:\nThe behavior of an object is defined by its methods, which are the functions and subroutines defined within the object class. Without class methods, a class would simply be a structure.\n")

print("Question NO. 5\n")

class cars():
    def __init__(self, modelyear, v_desc, color, price, seats):
        self.modelyear = modelyear
        self.color = color
        self.v_desc = v_desc
        self.price = price
        self.seats = seats
    

    def reg_no(self,nregno):
        print("\tReg No. is : {}".format(nregno))

    def ins(self,ninsu):
        print("\tInsurance : (YES/NO) : {}".format(ninsu))

    def tracker(self,ntrk):
        print("\tTracker Installed : (YES/NO) : {}".format(ntrk))

car1 = cars("2019", "Suzuki Wagon R","White", 1510000, 5)
car2 = cars("2016","Toyota Passo","Red",2150000,4)
car3 = cars("2014","Toyota Aygo","Black",1925000,4)
car4 = cars("2014","Honda Civic Prosmatic","Silver",1600000,4)
car5 = cars("2006","Daihatsu Mira", "Blue", 890000,4)


print("These 5 Vehicles are availble for Sale : \n")
print()

print("Vehicle 1 Detail\n\n")
print("\tModel Year {}".format(car1.modelyear))
print("\tVehicle Description {}".format(car1.v_desc))
print("\tColor {}".format(car1.modelyear))
print("\tPrice {}".format(car1.price))
print("\tSeats {}".format(car1.seats))
car1.reg_no("BAC-400")
car1.ins("Yes")
car1.tracker("Yes")
print()
print()

print("Vehicle 2 Detail\n\n")
print("\tModel Year {}".format(car2.modelyear))
print("\tVehicle Description {}".format(car2.v_desc))
print("\tColor {}".format(car2.modelyear))
print("\tPrice {}".format(car2.price))
print("\tSeats {}".format(car2.seats))
car2.reg_no("CDC-900")
car2.ins("No")
car2.tracker("Yes")
print()
print()

print("Vehicle 3 Detail\n\n")
print("\tModel Year {}".format(car3.modelyear))
print("\tVehicle Description {}".format(car3.v_desc))
print("\tColor {}".format(car3.modelyear))
print("\tPrice {}".format(car3.price))
print("\tSeats {}".format(car3.seats))
car3.reg_no("CAA-645")
car3.ins("Yes")
car3.tracker("Yes")
print()
print()

print("Vehicle 4 Detail\n\n")
print("\tModel Year {}".format(car4.modelyear))
print("\tVehicle Description {}".format(car4.v_desc))
print("\tColor {}".format(car4.modelyear))
print("\tPrice {}".format(car4.price))
print("\tSeats {}".format(car4.seats))
car4.reg_no("Non Registered")
car4.ins("No")
car4.tracker("Yes")
print()
print()

print("Vehicle 5 Detail\n\n")
print("\tModel Year {}".format(car5.modelyear))
print("\tVehicle Description {}".format(car5.v_desc))
print("\tColor {}".format(car5.modelyear))
print("\tPrice {}".format(car5.price))
print("\tSeats {}".format(car5.seats))
car5.reg_no("ANC-541")
car5.ins("Yes")
car5.tracker("No")
print()
print()
# Out:
# Assignment 6
#
# Question NO. 1
#
# Define Object Oriented Programming Language
#
# Object-oriented programming (OOP) refers to a type of computer programming (software design) in which programmers define the data type of a data structure, and also the types of operations (functions) that can be applied to the data structure. In this way, the data structure becomes an object that includes both data and functions. In addition, programmers can create relationships between one object and another. For example, objects can inherit characteristics from other objects.
#
# Question NO. 2
#
# List down the Benefits of OOP?
#
# 1. Improved software-development productivity.
# 2. Improved software maintainability.
# 3. Faster development.
# 4. Lower cost of development.
# 5. Higher-quality software
#
# Question NO. 3
#
# Differentiate between function and method?
#
# Function — a set of instructions that perform a task.
# Method — a set of instructions that are associated with an object.
# ...
