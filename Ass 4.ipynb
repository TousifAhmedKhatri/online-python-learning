# %%
print("\nAssignment 4\n")

print("Question No. 1\n")
st_det = {
"first_name" : "Mr. A",
"last_name" : "Mr. B",
"age": 10,
"city" : "Karachi"
}
print("Student Data\n")
print("Student First Name : " + st_det["first_name"])
print("Student Last Name : " + st_det["last_name"])
print("Student Age : " + str(st_det["age"]))
print("Student City : " + st_det["city"])
print()

nd = {"Qualification" : "Metric"}
st_det.update(nd)

print("Student Data - Update List (Add Qualification)\n")
print("Student First Name : " + st_det["first_name"])
print("Student Last Name : " + st_det["last_name"])
print("Student Age : " + str(st_det["age"]))
print("Student City : " + st_det["city"])
print("Student Qualification : " + st_det["Qualification"])
print()

del st_det["Qualification"]
print("Student Data - Update List (Remove Qualification)\n")
print("Student First Name : " + st_det["first_name"])
print("Student Last Name : " + st_det["last_name"])
print("Student Age : " + str(st_det["age"]))
print("Student City : " + st_det["city"])

print()

print("Question No. 2\n")

cities = {
    "Karachi" : 
        {
        "Population" : 10500000,
        "Main Area" : "Saddar",
        "Country" : "Pakistan"
        },
    "Paris" :
        {
        "Population" : 5645673,
        "Main Area" : "Gulberg",
        "Country" : "France"
        },
    "Doha" :
        {
        "Population" : 784510234,
        "Main Area" : "Sector G5-8",
        "Country" : "Qatar"
        }
}

print(cities)

for citynm, citydet in cities.items():
    print ("The name of City is : "+citynm)
    print("\tIts Population is : " + str(citydet["Population"]))
    print("\tIts Main Area is : " + citydet["Main Area"])
    print("\tIt is located in : " + citydet["Country"])
    print()


print("Question No. 3\n")
age=input("Enter age : ")
age=0
age=int(age)

if (age<3):
    fee="Free"
elif (age>=3) and (age<=12):
    fee=10
elif (age>12):
    fee=15

print("The Fee is : " + str(fee))

print("Question No. 4\n")

def favbook (bookname):
    print("One of my Fav book is : " + bookname)

BN=input("Kindly Enter Book Name : ")
favbook(BN)

print("Question No. 5\n")

import random
rn = random.randint(1,101)
rn=int(rn)
       
   

for a in range (1,4):
    uin = input("Guess The Number : ")
    uin=int(uin)
    if (uin == rn):
        print("You win, The number is : "+str(uin))
        break
    elif (uin > rn):
        print("Your guess is greater then correct anser, please try again") 
        
    elif (uin < rn):
        print("Your guess is less then correct anser, please try again") 
    
if (uin!=rn):
        print("Sorry No winn, please try again")
# Out:
# Assignment 4
#
# Question No. 1
#
# Student Data
#
# Student First Name : Mr. A
# Student Last Name : Mr. B
# Student Age : 10
# Student City : Karachi
#
# Student Data - Update List (Add Qualification)
#
# Student First Name : Mr. A
# Student Last Name : Mr. B
# Student Age : 10
# Student City : Karachi
# Student Qualification : Metric
#
# Student Data - Update List (Remove Qualification)
#
# Student First Name : Mr. A
# Student Last Name : Mr. B
# Student Age : 10
# Student City : Karachi
#
# Question No. 2
#
# {'Karachi': {'Population': 10500000, 'Main Area': 'Saddar', 'Country': 'Pakistan'}, 'Paris': {'Population': 5645673, 'Main Area': 'Gulberg', 'Country': 'France'}, 'Doha': {'Population': 784510234, 'Main Area': 'Sector G5-8', 'Country': 'Qatar'}}
# The name of City is : Karachi
# 	Its Population is : 10500000
# 	Its Main Area is : Saddar
# 	It is located in : Pakistan
#
# The name of City is : Paris
# 	Its Population is : 5645673
# 	Its Main Area is : Gulberg
# ...
